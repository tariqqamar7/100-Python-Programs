# %% [markdown]
# Question : Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5,
# between 2000 and 3200 (both included).
# The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
a = []
for i in range(2000,3200):
    if i%7 == 0 and i%5 != 0:
        a.append(str(i))
        print(','.join(a),end="")
# Out:
# 20022002,20092002,2009,20162002,2009,2016,20232002,2009,2016,2023,20372002,2009,2016,2023,2037,20442002,2009,2016,2023,2037,2044,20512002,2009,2016,2023,2037,2044,2051,20582002,2009,2016,2023,2037,2044,2051,2058,20722002,2009,2016,2023,2037,2044,2051,2058,2072,20792002,2009,2016,2023,2037,2044,2051,2058,2072,2079,20862002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,20932002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,21072002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,21142002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,21212002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,21282002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,21422002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,21492002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,21562002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,21632002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,21772002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,21842002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,21912002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,21982002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,22122002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,22192002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,22262002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,22332002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,22472002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,22542002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,22612002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,22682002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,22822002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,22892002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,22962002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,23032002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,23172002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,23242002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,23312002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233 ...

# %% [markdown]
# Question : Write a program which can compute the factorial of a given numbers.
# The results should be printed in a comma-separated sequence on a single line.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n*factorial(n-1)
print(','.join(str(factorial(8))))
# Out:
# 4,0,3,2,0

# %% [markdown]
# Question: With a given integral number n, write a program to generate a dictionary that contains (i, i*i) such that is an integral number between 1 and n (both included). and then the program should print the dictionary.

# %%
# input : 5
# {1:1,2:4,3:9,4:16,5:25}
dic = dict()
n = int(input("Enter numbers to generate a dictionary : "))
for i in range(1,n+1):
    dic[i] = i*i
print(dic)
# Out:
# Enter numbers to generate a dictionary : 5
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# Question: Write a program which accepts a sequence of comma-separated numbers from console and generate a list and a tuple which contains every number.

# %%
seq = input("Enter a sequence of comma-seprated numbers: ")
l = list(seq.split(','))
t = tuple(seq.split(','))
print("List: ",l,"\nTuple: ",t,end="")
# Out:
# Enter a sequence of comma-seprated numbers: 1,2,3,4,5
# List:  ['1', '2', '3', '4', '5']
# Tuple:  ('1', '2', '3', '4', '5')

# %% [markdown]
# Question:
# Define a class which has at least two methods:
# - getString: to get a string from console input
# - printString: to print the string in upper case.
# - Also please include simple test function to test the class methods.

# %%
class Twomethods():
    def getString(self):
        self.string = input("Enter String: ")
    def printString(self):
        print(self.string)
obj = Twomethods()
obj.getString()
obj.printString()
# Out:
# Enter String: My Name is Tariq Qamar
# My Name is Tariq Qamar

# %% [markdown]
# Question: Write a program that calculates and prints the value according to the given formula:
# - Q = Square root of [(2 * C * D)/H]
# - Following are the fixed values of C and H: C is 50. H is 30.
# - D is the variable whose values should be input to your program in a comma-separated sequence.

# %%
import math
C,H = 50,30
d = input("Enter Comma-seprated Values: ")
d = d.split(',')
l = []
for i in d:
    aa = (2*C*int(i))/H
    q = round(math.sqrt(aa))
    l.append(str(q))
print(','.join(l))
# Out:
# Enter Comma-seprated Values: 100,150,180
# 18,22,24
